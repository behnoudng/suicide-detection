# %%
import pandas as pd
df_train = pd.read_csv("train_preprocessed.csv")
df_test = pd.read_csv("test_preprocessed.csv")

# %%
df_train.head()
# Out:
#                                                 text        class  \
# 0  normalise watching dubbed anime i don’t care i...  non-suicide
# 1  sad gorl hours I have school in a few minutes ...  non-suicide
# 2  Every little problem makes me want to kill mys...      suicide
# 3  Is wanting to die unhealthy?I was just reading...      suicide
# 4  THE REDDIT APP ICON IS GOOD AGAIN It looks so ...  non-suicide
#
#                                       processed_text
# 0  normalise watching dubbed anime dont care not ...
# 1  sad gorl hour school minute feel like fuckin s...
# 2  every little problem make want kill myself.tin...
# 3  wanting die unhealthy reading submission made ...
# 4       reddit app icon good look weird seeing color

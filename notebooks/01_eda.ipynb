# %%
import pandas as pd
data = pd.read_csv("../data/raw/suicide_data.csv")
data = data.drop(columns=["Unnamed: 0"], axis=1)
data
# Out:
#         Unnamed: 0                                               text  \
# 0                2  Ex Wife Threatening SuicideRecently I left my ...
# 1                3  Am I weird I don't get affected by compliments...
# 2                4  Finally 2020 is almost over... So I can never ...
# 3                8          i need helpjust help me im crying so hard
# 4                9  I’m so lostHello, my name is Adam (16) and I’v...
# ...            ...                                                ...
# 232069      348103  If you don't like rock then your not going to ...
# 232070      348106  You how you can tell i have so many friends an...
# 232071      348107  pee probably tastes like salty tea😏💦‼️ can som...
# 232072      348108  The usual stuff you find hereI'm not posting t...
# 232073      348110  I still haven't beaten the first boss in Hollo...
#
#               class
# 0           suicide
# 1       non-suicide
# 2       non-suicide
# 3           suicide
# 4           suicide
# ...             ...
# 232069  non-suicide
# 232070  non-suicide
# 232071  non-suicide
# 232072      suicide
# 232073  non-suicide
#
# [232074 rows x 3 columns]

# %%
data[data["class"] != "suicide"][["text"]].iloc[1].to_list()
# Out:
# ['Finally 2020 is almost over... So I can never hear "2020 has been a bad year" ever again. I swear to fucking God it\'s so annoying']

# %%
data['class'].value_counts(normalize=True) * 100
# Out:
# class
# suicide        50.0
# non-suicide    50.0
# Name: proportion, dtype: float64

# %%
train_df = pd.read_csv("../data/processed/train.csv")
test_df = pd.read_csv("../data/processed/test.csv")
metadata = pd.read_json("../data/processed/metadata.json")

print(f"TRAIN:\n{train_df.head()}")
print(f"\n\nTEST:\n{test_df.head()}")
print(f"\n\nMETADATA:\n{metadata}")
# Out:
# TRAIN:
#                                                 text        class
# 0  normalise watching dubbed anime i don’t care i...  non-suicide
# 1  sad gorl hours I have school in a few minutes ...  non-suicide
# 2  Every little problem makes me want to kill mys...      suicide
# 3  Is wanting to die unhealthy?I was just reading...      suicide
# 4  THE REDDIT APP ICON IS GOOD AGAIN It looks so ...  non-suicide
#
#
# TEST:
#                                                 text        class
# 0  Why do reposts or karma whores matter so much?...  non-suicide
# 1  I took 500mg of Trazodone last nightShould I b...      suicide
# 2  I'm seriously think suicide is the only way to...      suicide
# 3  I think I am doneI cannot continue like this a...      suicide
# 4  Losing the fightIt's been 5 years, and the dep...      suicide
#
#
# METADATA:
#              train_size  test_size  total_size  classes  test_split
# suicide          185659      46415      232074    92830         0.2
# non-suicide      185659      46415      232074    92829         0.2
